# %%
import pandas as pd

# %%
table
# Out:
#    TransactionID    ClientID       Profession    Bank_dep      Risk   \
# 0               1         231   Self-employed            9     High
# 1               2         765        students            5     high
# 2               3         453          Horeca            7   medium
# 3               4         231   self-employed            9     high
# 4               5         892         finance            3      low
#
#     Number of credits    Revenue
# 0                    2      30200
# 1                    3      12700
# 2                    5      89400
# 3                    2      30200
# 4                    3     740000

# %%
# table with Method, Library, Code, Result

main = pd.DataFrame(columns=["Method","Library","Code","Results"])

# %%
main["Method"]= ["Dummy encoder","Label Encoder","Ordinal"]

# %%
main
# Out:
#           Method Library Code Results
# 0  Dummy encoder     NaN  NaN     NaN
# 1  Label Encoder     NaN  NaN     NaN
# 2        Ordinal     NaN  NaN     NaN

# %%
# Dummy encoder

dummy_encod = pd.get_dummies(table, prefix=["Profession", "Risk"])

# %%
dummy_encod
# Out:
#    TransactionID    ClientID    Bank_dep    Number of credits    Revenue   \
# 0               1         231           9                    2      30200
# 1               2         765           5                    3      12700
# 2               3         453           7                    5      89400
# 3               4         231           9                    2      30200
# 4               5         892           3                    3     740000
#
#    Profession_ Horeca   Profession_ Self-employed   Profession_ finance   \
# 0                    0                           1                     0
# 1                    0                           0                     0
# 2                    1                           0                     0
# 3                    0                           0                     0
# 4                    0                           0                     1
#
#    Profession_ self-employed   Profession_ students   Risk_ High   \
# ...

# %%
main.loc[0,"Library"]= "Pandas"
main.loc[0,"Code"]="""dummy_encod = pd.get_dummies(table, prefix=["Profession", "Risk"])"""
main.loc[0,"Results"]= "This method takes all categorical data (Profession and Risk), and split the values into individual variable so that each value is numerical. However we can see that this is case sensitive as same words are considered as different variable depending on presence of capital letters"
main
# Out:
#           Method Library                                               Code  \
# 0  Dummy encoder  Pandas  dummy_encod = pd.get_dummies(table, prefix=["P...
# 1  Label Encoder     NaN                                                NaN
# 2        Ordinal     NaN                                                NaN
#
#                                              Results
# 0  This method takes all categorical data (Profes...
# 1                                                NaN
# 2                                                NaN

# %%
# Label encoder
from sklearn.preprocessing import LabelEncoder
import numpy as np
label_encode=LabelEncoder()

# %%
label_encod=pd.read_table("DAFT_0116/Module_1/Lab_32_Encoding/table_to_import.txt", sep= "|")

# %%
label_encod
# Out:
#    TransactionID    ClientID       Profession    Bank_dep      Risk   \
# 0               1         231   Self-employed            9     High
# 1               2         765        students            5     high
# 2               3         453          Horeca            7   medium
# 3               4         231   self-employed            9     high
# 4               5         892         finance            3      low
#
#     Number of credits    Revenue
# 0                    2      30200
# 1                    3      12700
# 2                    5      89400
# 3                    2      30200
# 4                    3     740000

# %%
label_encode.fit_transform(table['Risk'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Risk'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   TransactionID        5 non-null      int64
#  1    ClientID            5 non-null      int64
#  2    Profession          5 non-null      object
#  3    Bank_dep            5 non-null      int64
#  4    Risk                5 non-null      object
#  5    Number of credits   5 non-null      int64
#  6    Revenue             5 non-null      int64
# dtypes: int64(5), object(2)
# memory usage: 408.0+ bytes

# %%
# Ordinal encoding
from sklearn.preprocessing import OrdinalEncoder
ordinal_encoder = OrdinalEncoder()

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8820\1989611696.py in <module>
# ----> 1 ordin_encod = label_encoder.fit_transform(table)
#       2 ordin_encod
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in fit_transform(self, y)
#     113             Encoded labels.
#     114         """
# --> 115         y = column_or_1d(y, warn=True)
#     116         self.classes_, y = _unique(y, return_inverse=True)
#     117         return y
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in column_or_1d(y, warn)
#    1036         return np.ravel(y)
#    1037
# -> 1038     raise ValueError(
#    1039         "y should be a 1d array, got an array of shape {} instead.".format(shape)
#    1040     )
#
# ValueError: y should be a 1d array, got an array of shape (5, 7) instead.

# %%
cols = ["TransactionID", "ClientID", "Profession", "Bank_dep", "Risk", "Number of credits", "Revenue"]
row_1 = [1,231,"Self-employed", 9, "High", 2, 30200]
row_2 = [2,765,"students",5,"high",3,12700]
row_3 = [3,453,"Horeca",7,"medium",5,89400]
row_4 = [4,231,"self-employed",9,"high",2,30200]
row_5 = [5,892,"finance",3,"low",3,740000]

# %%
data = pd.DataFrame([row_1,row_2,row_3,row_4,row_5], columns=cols)

# %%
data
# Out:
#    TransactionID  ClientID     Profession  Bank_dep    Risk  \
# 0              1       231  Self-employed         9    High
# 1              2       765       students         5    high
# 2              3       453         Horeca         7  medium
# 3              4       231  self-employed         9    high
# 4              5       892        finance         3     low
#
#    Number of credits  Revenue
# 0                  2    30200
# 1                  3    12700
# 2                  5    89400
# 3                  2    30200
# 4                  3   740000

# %%
lab_encod = label_encode.fit_transform(data['Risk'])

# %%
lab_encod
# Out:
# array([0, 1, 3, 1, 2])

# %%
lab_encod2 = label_encode.fit_transform(data['Profession'])

# %%
lab_encod2
# Out:
# array([1, 4, 0, 3, 2])

# %%
data["Profession_labels"]=lab_encod2

# %%
data
# Out:
#    TransactionID  ClientID     Profession  Bank_dep    Risk  \
# 0              1       231  Self-employed         9    High
# 1              2       765       students         5    high
# 2              3       453         Horeca         7  medium
# 3              4       231  self-employed         9    high
# 4              5       892        finance         3     low
#
#    Number of credits  Revenue  Profession_labels
# 0                  2    30200                  1
# 1                  3    12700                  4
# 2                  5    89400                  0
# 3                  2    30200                  3
# 4                  3   740000                  2

# %%
main.loc[1,"Library"]= "Sklearn.preprocessing"
main.loc[1,"Code"]="""lab_encod = label_encode.fit_transform(data['Risk'])"""
main.loc[1,"Results"]= "This method takes all categorical data (Profession and Risk), and split the values into kind of scale so that each value is numerical, however, there doesn't seem to have a particular order and this is still case sensitive "
main
# Out:
#           Method                Library  \
# 0  Dummy encoder                 Pandas
# 1  Label Encoder  Sklearn.preprocessing
# 2        Ordinal                    NaN
#
#                                                 Code  \
# 0  dummy_encod = pd.get_dummies(table, prefix=["P...
# 1  lab_encod = label_encode.fit_transform(data['R...
# 2                                                NaN
#
#                                              Results
# 0  This method takes all categorical data (Profes...
# 1  This method takes all categorical data (Profes...
# 2                                                NaN

# %%
import numpy as np
ord_encod=ordinal_encoder.fit_transform(data)

# extracting "Profession" column as a 2D array
temp_prof = data[['Profession']].values

#  ordinal encoding on the "Profession" array
prof_encoded = ordinal_encoder.fit_transform(temp_prof)

# adding it back to the table
data['Profession_labels2'] = prof_encoded.flatten().astype(int)

# %%
data
# Out:
#    TransactionID  ClientID     Profession  Bank_dep    Risk  \
# 0              1       231  Self-employed         9    High
# 1              2       765       students         5    high
# 2              3       453         Horeca         7  medium
# 3              4       231  self-employed         9    high
# 4              5       892        finance         3     low
#
#    Number of credits  Revenue  Profession_labels  Profession_labels2
# 0                  2    30200                  1                   1
# 1                  3    12700                  4                   4
# 2                  5    89400                  0                   0
# 3                  2    30200                  3                   3
# 4                  3   740000                  2                   2

# %%
main.loc[2,"Library"]= "Sklearn.preprocessing"
main.loc[2,"Code"]="""# extracting "Profession" column as a 2D array 
temp_prof = data[['Profession']].values

#  ordinal encoding on the "Profession" array
prof_encoded = ordinal_encoder.fit_transform(temp_prof)

# adding it back to the table
data['Profession_labels2'] = prof_encoded.flatten().astype(int)"""
main.loc[2,"Results"]= "It gives the same results as the previous method"
main
# Out:
#           Method                Library  \
# 0  Dummy encoder                 Pandas
# 1  Label Encoder  Sklearn.preprocessing
# 2        Ordinal  Sklearn.preprocessing
#
#                                                 Code  \
# 0  dummy_encod = pd.get_dummies(table, prefix=["P...
# 1  lab_encod = label_encode.fit_transform(data['R...
# 2  # extracting "Profession" column as a 2D array...
#
#                                              Results
# 0  This method takes all categorical data (Profes...
# 1  This method takes all categorical data (Profes...
# 2   It gives the same results as the previous method
