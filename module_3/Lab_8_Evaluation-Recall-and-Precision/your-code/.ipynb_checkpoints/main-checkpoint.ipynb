# %% [markdown]
# # Evaluation: Precision & Recall
# ## Using the evaluation metrics we have learned, we are going to compare how well some different types of classifiers perform on different evaluation metrics
# ### We are going to use a dataset of written numbers which we can import from sklearn. Run the code below to do so.

# %%
import numpy as np
from sklearn.datasets import fetch_openml
mnist = fetch_openml('mnist_784')
X, y = mnist['data'], mnist['target']

# %% [markdown]
# ### Now take a look at the shapes of the X and y matricies

# %%
print(X.shape)
print(y.shape)
# Out:
# (70000, 784)
# (70000,)

# %% [markdown]
# ### Now, let's pick one entry and see what number is written. Use indexing to pick the 36000th digit

# %%
digit = X.loc[[36000]]

# %% [markdown]
# ### You can use the .reshape(28,28) function and plt.imshow() function with the parameters cmap = matplotlib.cm.binary, interpolation="nearest" to make a plot of the number. Be sure to import matplotlib!

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
digit_reshape = digit.values.reshape(28,28)
plt.imshow(digit_reshape, cmap=mpl.cm.binary, interpolation="nearest")

# %% [markdown]
# ### Use indexing to see if what the plot shows matches with the outcome of the 36000th index

# %%
y[36000]
# Out:
# '9'

# %% [markdown]
# ### Now lets break into a test train split to run a classification. Instead of using sklearn, use indexing to select the first 60000 entries for the training, and the rest for training.

# %%
X_train=X.head(60000)
X_test=X.tail(10000)
y_train=y.head(60000)
y_test=y.tail(10000)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((60000, 784), (10000, 784), (60000,), (10000,))

# %% [markdown]
# ### We are going to make a two-class classifier, so lets restrict to just one number, for example 5s. Do this by defining a new y training and y testing sets for just the number 5

# %%
y_train_5 = np.where(y_train == '5', 1, 0)
y_test_5 = np.where(y_test == '5', 1, 0)

# %%
print(y_test_5)
# Out:
# [0 0 0 ... 0 1 0]

# %% [markdown]
# ### Lets train a logistic regression to predict if a number is a 5 or not (remember to use the 'just 5s' y training set!)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PowerTransformer
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix
from sklearn.metrics import plot_confusion_matrix

log_model = LogisticRegression()

#log_model.fit(X_train, y_train_5)

trans = PowerTransformer()

trans.fit(X_train)

X_train_mod = trans.transform(X_train)
X_test_mod = trans.transform(X_test)

log_model.fit(X_train_mod, y_train_5)

y_pred_train_log = log_model.predict(X_train_mod)
y_pred_test_log = log_model.predict(X_test_mod)
# Out:
# C:\Users\buldu\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:3253: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
# C:\Users\buldu\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ### Does the classifier predict correctly the 36000th digit we picked before?

# %%
print(log_model.predict(X_train_mod[[36000]]))
# Out:
# [0]

# %% [markdown]
# ### To make some comparisons, we are going to make a very dumb classifier, that never predicts 5s. Build the classifier with the code below, and call it using: never_5_clf = Never5Classifier()

# %%
from sklearn.base import BaseEstimator
class Never5Classifier(BaseEstimator):
    def fit(self, X, y=None):
        pass
    def predict(self, X):
        return np.zeros((len(X), 1), dtype=bool)

never_5_clf = Never5Classifier()

# %% [markdown]
# ### Now lets fit and predict on the testing set using our never 5 Classifier

# %%
never_5_clf.fit(X_train_mod, y_train_5)

y_pred_train_never = never_5_clf.predict(X_train_mod)
y_pred_test_never = never_5_clf.predict(X_test_mod)

# %% [markdown]
# ### Let's compare this to the Logistic Regression. Examine the confusion matrix, precision, recall, and f1_scores for each. What is the probability cutoff you are using to decide the classes?

# %%
import pandas as pd
performance_log = pd.DataFrame({'Error_metric': ['Accuracy','Precision','Recall'],
                               'Train': [accuracy_score(y_train_5, y_pred_train_log),
                                         precision_score(y_train_5, y_pred_train_log),
                                         recall_score(y_train_5, y_pred_train_log)],
                               'Test': [accuracy_score(y_test_5, y_pred_test_log),
                                        precision_score(y_test_5, y_pred_test_log),
                                        recall_score(y_test_5, y_pred_test_log)]})

display(performance_log)

print("Confusion matrix for the train set")
print(confusion_matrix(y_train_5,y_pred_train_log))
plot_confusion_matrix(log_model,X_train_mod,y_train_5, values_format = 'd')
plt.show()

print()
print()

print("Confusion matrix for the test set")
print(confusion_matrix(y_test_5, y_pred_test_log))
plot_confusion_matrix(log_model,X_test_mod,y_test_5, values_format = 'd')
plt.show()
# Out:
#   Error_metric     Train      Test
# 0     Accuracy  0.975300  0.975500
# 1    Precision  0.906502  0.914213
# 2       Recall  0.810183  0.800448
# Confusion matrix for the train set
# [[54126   453]
#  [ 1029  4392]]
# C:\Users\buldu\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# Confusion matrix for the test set
# [[9041   67]
#  [ 178  714]]
# C:\Users\buldu\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ### What are the differences you see? Without knowing what each model is, what can these metrics tell you about how well each works?

# %%
from sklearn.metrics import ConfusionMatrixDisplay

performance_log = pd.DataFrame({'Error_metric': ['Accuracy','Precision','Recall'],
                               'Train': [accuracy_score(y_train_5, y_pred_train_never),
                                         precision_score(y_train_5, y_pred_train_never),
                                         recall_score(y_train_5, y_pred_train_never)],
                               'Test': [accuracy_score(y_test_5, y_pred_test_never),
                                        precision_score(y_test_5, y_pred_test_never),
                                        recall_score(y_test_5, y_pred_test_never)]})

display(performance_log)

print("Confusion matrix for the train set")
print(confusion_matrix(y_train_5,y_pred_train_never))
#plot_confusion_matrix(never_5_clf.predict,X_train_mod,y_train_5, values_format = 'd')
#plt.show()
cm = confusion_matrix(y_pred_train_never, y_train_5)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0,1])
disp.plot()

print("Confusion matrix for the test set")
print(confusion_matrix(y_test_5, y_pred_test_never))
#plot_confusion_matrix(never_5_clf.predict,X_test_mod,y_test_5, values_format = 'd')
#plt.show()
cm2 = confusion_matrix(y_pred_test_never, y_test_5)
disp2 = ConfusionMatrixDisplay(confusion_matrix=cm2, display_labels=[0,1])
disp2.plot()
# Out:
# C:\Users\buldu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\buldu\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#   Error_metric    Train    Test
# 0     Accuracy  0.90965  0.9108
# 1    Precision  0.00000  0.0000
# 2       Recall  0.00000  0.0000
# Confusion matrix for the train set
# [[54579     0]
#  [ 5421     0]]
# Confusion matrix for the test set
# [[9108    0]
#  [ 892    0]]

# %% [markdown]
# ### Now let's examine the roc_curve for each. Use the roc_curve method from sklearn.metrics to help plot the curve for each

# %%
from sklearn.metrics import roc_curve, auc
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# Predict probabilities for the test set
probs = log_model.predict_proba(X_test)[:, 1]
# Compute the false positive rate, true positive rate, and thresholds
fpr, tpr, thresholds = roc_curve(y_test_5, probs)
# Compute the Area Under the Curve (AUC)
roc_auc_log = auc(fpr, tpr)



# Plot the ROC curve
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc_log)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve - Logistic Regression')
plt.legend(loc='lower right')
plt.show()
# Out:
# C:\Users\buldu\anaconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
# Predict probabilities for the test set
# Compute the false positive rate, true positive rate, and thresholds
fpr, tpr, thresholds = roc_curve(y_test_5, y_pred_test_never)
# Compute the Area Under the Curve (AUC)
roc_auc_never = auc(fpr, tpr)


plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc_never)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve - Logistic Regression - Never 5 classifiers')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ### Now find the roc_auc_score for each.

# %%
print(roc_auc_log)
print(roc_auc_never)
# Out:
# 0.9682711300960473
# 0.5

# %% [markdown]
# ### What does this metric tell you? Which classifier works better with this metric in mind?

# %%
# Logistic regression : has high predictive power, 
# as it is able to distinguish 5 vs the others with great degree of accuracy .
# the never5classifier is basically random guessing when it's 0.5
