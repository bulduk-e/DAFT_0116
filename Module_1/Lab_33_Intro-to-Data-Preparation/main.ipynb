# %%
import pandas as pd

# %%
# Part 1: upload the data
df = pd.read_excel("C:/Users/buldu/DAFT_0116/Module_1/Lab_33_Intro-to-Data-Preparation/example_data_cleaning.xlsx")

# %%
df.head(30)
# Out:
#     TransactionID  ClientID    BirthYear   Amount   Profession  Department  \
# 0               4     34985  1923.000000     5670      manager          78
# 1              16     34997  1923.000000  2399090    developer          78
# 2              25     35006  1923.000000    33050           HR          78
# 3              12     34993  1939.142857    23430    professor          78
# 4              21     35002  1939.142857    16770      manager          78
# 5              11     34992  1943.857143    21210   researcher          78
# 6              20     35001  1943.857143    14550      student          78
# 7               3     34984  1945.000000     3450      student          78
# 8              19     35000  1948.571429    12330       barmen          78
# 9               9     34990  1953.285714    16770      Manager          78
# 10              8     34989  1958.000000    14550           HR          78
# ...

# %%
# Part 3 : Cleansing data

# %%
# make birthyear as in integer, currently a float. Before we have to put value for the two missing.
# client 34987 and 34988

client_miss_year = df[df['ClientID'].isin([34987, 34988])]
client_miss_year
# Out:
#     TransactionID  ClientID  BirthYear  Amount Profession  Department    Risk
# 11              6     34987     1967.0   10110    Manager          78  Medium
# 12             15     34987     1967.0   30090    Manager          78     Low
# 22             23     34988     1999.0   25650    Manager          78     Low
# 28             22     34987        NaN   18990     sailer          78    High
# 29              7     34988        NaN   12330    Manager          78  Medium

# %%
#Thus we can assign 1967 to index 28 and 1999 to index 29
df["BirthYear"].fillna(0, inplace=True)
df.loc[28,"BirthYear"]= 1967
df.loc[29,"BirthYear"]= 1999
df
# Out:
#     TransactionID  ClientID    BirthYear   Amount   Profession  Department  \
# 0               4     34985  1923.000000     5670      manager          78
# 1              16     34997  1923.000000  2399090    developer          78
# 2              25     35006  1923.000000    33050           HR          78
# 3              12     34993  1939.142857    23430    professor          78
# 4              21     35002  1939.142857    16770      manager          78
# 5              11     34992  1943.857143    21210   researcher          78
# 6              20     35001  1943.857143    14550      student          78
# 7               3     34984  1945.000000     3450      student          78
# 8              19     35000  1948.571429    12330       barmen          78
# 9               9     34990  1953.285714    16770      Manager          78
# 10              8     34989  1958.000000    14550           HR          78
# ...

# %%
# Transform to int
import math

df['BirthYear'] = df['BirthYear'].apply(lambda x: math.floor(x))
df
# Out:
#     TransactionID  ClientID  BirthYear   Amount   Profession  Department  \
# 0               4     34985       1923     5670      manager          78
# 1              16     34997       1923  2399090    developer          78
# 2              25     35006       1923    33050           HR          78
# 3              12     34993       1939    23430    professor          78
# 4              21     35002       1939    16770      manager          78
# 5              11     34992       1943    21210   researcher          78
# 6              20     35001       1943    14550      student          78
# 7               3     34984       1945     3450      student          78
# 8              19     35000       1948    12330       barmen          78
# 9               9     34990       1953    16770      Manager          78
# 10              8     34989       1958    14550           HR          78
# 11              6     34987       1967    10110      Manager          78
# ...

# %%
# removing outliers based on "Amount" using the most common method

stats = df.describe().transpose()
stats['IQR'] = stats['75%'] - stats['25%']
stats
# Out:
#                count           mean            std      min       25%  \
# TransactionID   30.0      15.500000       8.803408      1.0      8.25
# ClientID        30.0   34993.833333       8.132876  34982.0  34987.25
# BirthYear       30.0    1969.200000      27.647286   1923.0   1945.75
# Amount          30.0  101009.666667  434261.568869   1230.0  12330.00
# Department      30.0      78.000000       0.000000     78.0     78.00
#
#                    50%       75%        max       IQR
# TransactionID     15.5     22.75       30.0     14.50
# ClientID       34991.5  34999.75    35008.0     12.50
# BirthYear       1967.0   1988.00     2017.0     42.25
# Amount         18990.0  29535.00  2399090.0  17205.00
# Department        78.0     78.00       78.0      0.00

# %%
outliers = pd.DataFrame(columns=df.columns)
outliers
# Out:
# Empty DataFrame
# Columns: [TransactionID, ClientID, BirthYear, Amount, Profession, Department, Risk]
# Index: []

# %%
for col in stats.index:
    iqr = stats.at[col,'IQR']
    cutoff = iqr * 1.5
    lower = stats.at[col,'25%'] - cutoff
    upper = stats.at[col,'75%'] + cutoff
    results = df[(df[col] < lower) | 
                   (df[col] > upper)].copy()
    results['Outlier'] = col
    outliers = outliers.append(results)

outliers
# Out:
# C:\Users\buldu\AppData\Local\Temp\ipykernel_22792\3576781266.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   outliers = outliers.append(results)
# C:\Users\buldu\AppData\Local\Temp\ipykernel_22792\3576781266.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   outliers = outliers.append(results)
# C:\Users\buldu\AppData\Local\Temp\ipykernel_22792\3576781266.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   outliers = outliers.append(results)
# C:\Users\buldu\AppData\Local\Temp\ipykernel_22792\3576781266.py:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   outliers = outliers.append(results)
# ...

# %%
# let's remove the index 1 transaction which is clearly an outliers
df.drop(index=1, inplace=True)
df
# Out:
#     TransactionID  ClientID  BirthYear  Amount   Profession  Department  \
# 0               4     34985       1923    5670      manager          78
# 2              25     35006       1923   33050           HR          78
# 3              12     34993       1939   23430    professor          78
# 4              21     35002       1939   16770      manager          78
# 5              11     34992       1943   21210   researcher          78
# 6              20     35001       1943   14550      student          78
# 7               3     34984       1945    3450      student          78
# 8              19     35000       1948   12330       barmen          78
# 9               9     34990       1953   16770      Manager          78
# 10              8     34989       1958   14550           HR          78
# 11              6     34987       1967   10110      Manager          78
# 12             15     34987       1967   30090      Manager          78
# ...

# %%
# Checking how are min, max, quartile now
stats = df.describe().transpose()
stats['IQR'] = stats['75%'] - stats['25%']
stats

# looks like min and max of amount() are quite close to respectively "min" and "max"
# Out:
#                count          mean           std      min      25%      50%  \
# TransactionID   29.0     15.482759      8.958718      1.0      8.0     15.0
# ClientID        29.0  34993.724138      8.254421  34982.0  34987.0  34991.0
# BirthYear       29.0   1970.793103     26.698554   1923.0   1948.0   1967.0
# Amount          29.0  21765.517241  14176.887525   1230.0  12330.0  18990.0
#
#                    75%      max      IQR
# TransactionID     23.0     30.0     15.0
# ClientID       35000.0  35008.0     13.0
# BirthYear       1988.0   2017.0     40.0
# Amount         27870.0  55250.0  15540.0

# %%
# harmonize name in Profession, by putting everything in capital letter

df["Profession"]=df["Profession"].str.upper()
df
# Out:
#     TransactionID  ClientID  BirthYear  Amount   Profession  Department  \
# 0               4     34985       1923    5670      MANAGER          78
# 2              25     35006       1923   33050           HR          78
# 3              12     34993       1939   23430    PROFESSOR          78
# 4              21     35002       1939   16770      MANAGER          78
# 5              11     34992       1943   21210   RESEARCHER          78
# 6              20     35001       1943   14550      STUDENT          78
# 7               3     34984       1945    3450      STUDENT          78
# 8              19     35000       1948   12330       BARMEN          78
# 9               9     34990       1953   16770      MANAGER          78
# 10              8     34989       1958   14550           HR          78
# 11              6     34987       1967   10110      MANAGER          78
# 12             15     34987       1967   30090      MANAGER          78
# ...

# %%
# dropping column departement
df.drop(columns="Department", inplace=True)
df
# Out:
#     TransactionID  ClientID  BirthYear  Amount   Profession    Risk
# 0               4     34985       1923    5670      MANAGER     Low
# 2              25     35006       1923   33050           HR    High
# 3              12     34993       1939   23430    PROFESSOR     Low
# 4              21     35002       1939   16770      MANAGER     Low
# 5              11     34992       1943   21210   RESEARCHER  Medium
# 6              20     35001       1943   14550      STUDENT  Medium
# 7               3     34984       1945    3450      STUDENT  Medium
# 8              19     35000       1948   12330       BARMEN    High
# 9               9     34990       1953   16770      MANAGER  Medium
# 10              8     34989       1958   14550           HR    High
# 11              6     34987       1967   10110      MANAGER  Medium
# 12             15     34987       1967   30090      MANAGER     Low
# 13             24     34989       1967   27870           HR  Medium
# ...

# %%
test = df.groupby("ClientID")["Profession"].value_counts()
test
# Client 34987 is 2 times manager, and one time sailer. Sailer is an odd profession and is probably wrong. I will replace this value by manager
# Out:
# ClientID  Profession
# 34982     STUDENT        1
# 34983     BARMEN         1
# 34984     STUDENT        1
# 34985     MANAGER        1
# 34986     HR             1
# 34987     MANAGER        2
#           SAILER         1
# 34988     MANAGER        2
# 34989     HR             2
# 34990     MANAGER        1
# 34991     BDM            2
# 34992     RESEARCHER     1
# 34993     PROFESSOR      1
# 34994     DRIVER         1
# 34995     HAIRDRESSER    1
# 34998     ETUDIENT       1
# 34999     ETUDIENT       1
# 35000     BARMEN         1
# 35001     STUDENT        1
# 35002     MANAGER        1
# 35006     HR             1
# 35007     ETUDIENT       1
# 35008     BDM            1
# Name: Profession, dtype: int64

# %%
client_miss_prof = df[df['ClientID'].isin([34987])]
client_miss_prof
# index 28 will be replaced
# Out:
#     TransactionID  ClientID  BirthYear  Amount Profession  Department    Risk
# 11              6     34987       1967   10110    MANAGER          78  Medium
# 12             15     34987       1967   30090    MANAGER          78     Low
# 28             22     34987       1967   18990     SAILER          78    High

# %%
# also looking for empty data
null_displ = df[(df['Profession'].isnull()==True)]
null_displ
# it is the same client 35008, let's look if other transaction exists
# Out:
#     TransactionID  ClientID  BirthYear  Amount Profession  Department    Risk
# 15             28     35008       1967   46370        NaN          78    High
# 16             29     35008       1976   50810        NaN          78  Medium

# %%
client_miss_prof = df[df['ClientID'].isin([35008])]
client_miss_prof
# it appears he is BDM, let's put this value

# so we have to replace Profession of index 28 with MANAGER and 15-16 with BDM
# Out:
#     TransactionID  ClientID  BirthYear  Amount Profession  Department    Risk
# 14             27     35008       1967   41930        BDM          78     Low
# 15             28     35008       1967   46370        NaN          78    High
# 16             29     35008       1976   50810        NaN          78  Medium

# %%
df["Profession"].fillna("", inplace=True)
df.loc[15,"Profession"]= "BDM"
df.loc[16,"Profession"]= "BDM"

# %%
df.loc[28,"Profession"]= "MANAGER"

# %%
df
# Out:
#     TransactionID  ClientID  BirthYear  Amount   Profession    Risk
# 0               4     34985       1923    5670      MANAGER     Low
# 2              25     35006       1923   33050           HR    High
# 3              12     34993       1939   23430    PROFESSOR     Low
# 4              21     35002       1939   16770      MANAGER     Low
# 5              11     34992       1943   21210   RESEARCHER  Medium
# 6              20     35001       1943   14550      STUDENT  Medium
# 7               3     34984       1945    3450      STUDENT  Medium
# 8              19     35000       1948   12330       BARMEN    High
# 9               9     34990       1953   16770      MANAGER  Medium
# 10              8     34989       1958   14550           HR    High
# 11              6     34987       1967   10110      MANAGER  Medium
# 12             15     34987       1967   30090      MANAGER     Low
# 13             24     34989       1967   27870           HR  Medium
# ...

# %%
#  replacing names misspelled
df.value_counts("Profession")

# 3 values are ETUDIENT instead of STUDENT: index 18, 21, 24
# Out:
# Profession
# MANAGER        8
# BDM            5
# HR             4
# ETUDIENT       3
# STUDENT        3
# BARMEN         2
# DRIVER         1
# HAIRDRESSER    1
# PROFESSOR      1
# RESEARCHER     1
# dtype: int64

# %%
df.loc[18,"Profession"]= "STUDENT"
df.loc[21,"Profession"]= "STUDENT"
df.loc[24,"Profession"]= "STUDENT"

# %%
df.value_counts("Profession")
# Out:
# Profession
# MANAGER        8
# STUDENT        6
# BDM            5
# HR             4
# BARMEN         2
# DRIVER         1
# HAIRDRESSER    1
# PROFESSOR      1
# RESEARCHER     1
# dtype: int64

# %%
# the data are now clean
df
# Out:
#     TransactionID  ClientID  BirthYear  Amount   Profession    Risk
# 0               4     34985       1923    5670      MANAGER     Low
# 2              25     35006       1923   33050           HR    High
# 3              12     34993       1939   23430    PROFESSOR     Low
# 4              21     35002       1939   16770      MANAGER     Low
# 5              11     34992       1943   21210   RESEARCHER  Medium
# 6              20     35001       1943   14550      STUDENT  Medium
# 7               3     34984       1945    3450      STUDENT  Medium
# 8              19     35000       1948   12330       BARMEN    High
# 9               9     34990       1953   16770      MANAGER  Medium
# 10              8     34989       1958   14550           HR    High
# 11              6     34987       1967   10110      MANAGER  Medium
# 12             15     34987       1967   30090      MANAGER     Low
# 13             24     34989       1967   27870           HR  Medium
# ...

# %%
# let's change the birthyear of the 3 born in 2013, 2015 and 2017. let's check if other transaction available for those client
client_weird_birth = df[df['ClientID'].isin([34982,34983,34994])]
client_weird_birth

# unfortunately no other transaction for each of them
# Out:
#     TransactionID  ClientID  BirthYear  Amount Profession    Risk
# 25              1     34982       2013   12900    STUDENT     Low
# 26              2     34983       2015    1230     BARMEN    High
# 27             13     34994       2017   25650     DRIVER  Medium

# %%
# let's apply the median to them
df.describe()

# the median (also the mode) is 1967
# Out:
#        TransactionID      ClientID    BirthYear        Amount
# count      29.000000     29.000000    29.000000     29.000000
# mean       15.482759  34993.724138  1970.793103  21765.517241
# std         8.958718      8.254421    26.698554  14176.887525
# min         1.000000  34982.000000  1923.000000   1230.000000
# 25%         8.000000  34987.000000  1948.000000  12330.000000
# 50%        15.000000  34991.000000  1967.000000  18990.000000
# 75%        23.000000  35000.000000  1988.000000  27870.000000
# max        30.000000  35008.000000  2017.000000  55250.000000

# %%
df.loc[25,"BirthYear"]= 1967
df.loc[26,"BirthYear"]= 1967
df.loc[27,"BirthYear"]= 1967

# %%
df
# Out:
#     TransactionID  ClientID  BirthYear  Amount   Profession    Risk
# 0               4     34985       1923    5670      MANAGER     Low
# 2              25     35006       1923   33050           HR    High
# 3              12     34993       1939   23430    PROFESSOR     Low
# 4              21     35002       1939   16770      MANAGER     Low
# 5              11     34992       1943   21210   RESEARCHER  Medium
# 6              20     35001       1943   14550      STUDENT  Medium
# 7               3     34984       1945    3450      STUDENT  Medium
# 8              19     35000       1948   12330       BARMEN    High
# 9               9     34990       1953   16770      MANAGER  Medium
# 10              8     34989       1958   14550           HR    High
# 11              6     34987       1967   10110      MANAGER  Medium
# 12             15     34987       1967   30090      MANAGER     Low
# 13             24     34989       1967   27870           HR  Medium
# ...

# %%
# also client 35001	and 34984 are born 1943	in 1945, but this is too old for student, let's add them
client_weird_job = df[df['ClientID'].isin([35001,34984])]
client_weird_job
# Out:
#    TransactionID  ClientID  BirthYear  Amount Profession    Risk
# 6             20     35001       1943   14550    STUDENT  Medium
# 7              3     34984       1945    3450    STUDENT  Medium

# %%
# Since there is no way of having a compromise with this (not numerical), let's make them "UNKNOWN"
df.loc[6,"Profession"]= "UNKNOWN"
df.loc[7,"Profession"]= "UNKNOWN"

# %%
df
# Out:
#     TransactionID  ClientID  BirthYear  Amount   Profession    Risk
# 0               4     34985       1923    5670      MANAGER     Low
# 2              25     35006       1923   33050           HR    High
# 3              12     34993       1939   23430    PROFESSOR     Low
# 4              21     35002       1939   16770      MANAGER     Low
# 5              11     34992       1943   21210   RESEARCHER  Medium
# 6              20     35001       1943   14550      UNKNOWN  Medium
# 7               3     34984       1945    3450      UNKNOWN  Medium
# 8              19     35000       1948   12330       BARMEN    High
# 9               9     34990       1953   16770      MANAGER  Medium
# 10              8     34989       1958   14550           HR    High
# 11              6     34987       1967   10110      MANAGER  Medium
# 12             15     34987       1967   30090      MANAGER     Low
# 13             24     34989       1967   27870           HR  Medium
# ...

# %%
# Part 4: Encoding categorical data
# First, the profession, with get_dummies because 

df = pd.get_dummies(df, columns=["Profession"])
df
# Out:
#     TransactionID  ClientID  BirthYear  Amount    Risk  Profession_BARMEN  \
# 0               4     34985       1923    5670     Low                  0
# 2              25     35006       1923   33050    High                  0
# 3              12     34993       1939   23430     Low                  0
# 4              21     35002       1939   16770     Low                  0
# 5              11     34992       1943   21210  Medium                  0
# 6              20     35001       1943   14550  Medium                  0
# 7               3     34984       1945    3450  Medium                  0
# 8              19     35000       1948   12330    High                  1
# 9               9     34990       1953   16770  Medium                  0
# 10              8     34989       1958   14550    High                  0
# 11              6     34987       1967   10110  Medium                  0
# 12             15     34987       1967   30090     Low                  0
# ...

# %%
# Now let's encode Risk with 
risk_map={"Low": 1, "Medium": 2,"High": 3}
df["Risk"]= df["Risk"].map(risk_map)

# %%
df
# Out:
#     TransactionID  ClientID  BirthYear  Amount  Risk  Profession_BARMEN  \
# 0               4     34985       1923    5670     1                  0
# 2              25     35006       1923   33050     3                  0
# 3              12     34993       1939   23430     1                  0
# 4              21     35002       1939   16770     1                  0
# 5              11     34992       1943   21210     2                  0
# 6              20     35001       1943   14550     2                  0
# 7               3     34984       1945    3450     2                  0
# 8              19     35000       1948   12330     3                  1
# 9               9     34990       1953   16770     2                  0
# 10              8     34989       1958   14550     3                  0
# 11              6     34987       1967   10110     2                  0
# 12             15     34987       1967   30090     1                  0
# ...

# %%
df.to_csv("C:/Users/buldu/DAFT_0116/Module_1/Lab_33_Intro-to-Data-Preparation/Final_database.csv")
